# %%
from assistCNN import podzial_klas_na_2
import pandas as pd
import numpy as np
import pickle
dane = 'ekstrakcja_przyklad.pickle'

# %%
dtf=pd.read_pickle(dane)
names=['ekstrakcja', 'klasa', 'indeks', 'X', 'Y']
dtf.to_pickle('treningMNF.pickle')
data_clear='treningMNF.pickle'
trainset=podzial_klas_na_2(data_clear)
trainset[1].to_pickle('validationMNF.pickle')
trainset[0].to_pickle('trainMNF.pickle')

# %%
dtf=pd.read_pickle(dane)
names=['ekstrakcja', 'klasa', 'indeks', 'X', 'Y']
dtf.rename(columns=names)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-451db4c4959f> in <module>()
#       1 dtf=pd.read_pickle(dane)
#       2 names=['ekstrakcja', 'klasa', 'indeks', 'X', 'Y']
# ----> 3 dtf.rename(columns=names)
#
# C:\WPy-3662\python-3.6.6.amd64\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     185         @wraps(func)
#     186         def wrapper(*args, **kwargs):
# --> 187             return func(*args, **kwargs)
#     188
#     189         if not PY2:
#
# C:\WPy-3662\python-3.6.6.amd64\lib\site-packages\pandas\core\frame.py in rename(self, *args, **kwargs)
#    3779         kwargs.pop('axis', None)
#    3780         kwargs.pop('mapper', None)
# -> 3781         return super(DataFrame, self).rename(**kwargs)
#    3782
#    3783     @Substitution(**_shared_doc_kwargs)
#
# ...

# %%
dtf
# Out:
#                                                    values     class  index  \
# 0       [-4.458406448364258, -3.8528027534484863, -0.7...      6210    607
# 1       [-4.041160583496094, -1.4821135997772217, 0.89...      6210    607
# 2       [-3.9558160305023193, -3.3693900108337402, 2.4...      6210    607
# 3       [-3.7926065921783447, -3.3523364067077637, 3.8...      6210    607
# 4       [-2.2023885250091553, -3.9063522815704346, 0.7...      6210    607
# 5       [-4.447980880737305, -2.2874224185943604, 0.58...      6210    607
# 6       [-3.4154841899871826, -3.2491583824157715, 1.2...      6210    607
# 7       [-2.9412689208984375, -2.3078129291534424, 3.3...      6210    607
# 8       [-3.367976188659668, -4.442888259887695, 4.805...      6210    607
# 9       [-3.5198771953582764, -3.8359181880950928, 5.7...      6210    607
# 10      [-2.521455764770508, -2.8698363304138184, 5.31...      6210    607
# ...

# %%
# Out:
# [  6  22  24  25  29  30  31  37  38  39  40  41  78  79  80  81  82  94
#   95  97 124 125 126 127 128 129 130 131 132 133 134 135 136 137 138 139
#  140 141 142 143 152 153 154 155 156 157 158 159 160 161 162 163 164 165
#  166 167 168 197 198 199 201 202 203 204 205 206 207 208 209 210 211 212
#  213 214 215 216 217 218 219 220 221 222 223 224 225 226 227 228 229 230
#  231 232 233 234 235 236 237 238 239 240 241 242 243 244 245 246 247 248
#  249 250 251 252 253 254 255 256 257 258 259 260 261 262 263 264 265 266
#  267 273 279 280 283 284 285 286 287 288 289 290 291 293 294 295 301 307
#  314 338 339 340 343 344 345 346 347 348 349 350 351 352 353 354 355 356
#  357 358 359 360 361 362 363 364 365 366 367 368 369 371 373 374 375 376
#  377 378 380 384 385 386 389 391 393 395 397 399 402 403 404 405 409 410
#  412 413 415 416 417 418 419 421 423 425 427 428 431 433 434 436 437 438
#  439 444 445 448 449 453 454 455 456 458 459 461 462 463 465 467 469 470
# ...
